# %%
import pandas.rpy.common as com
filename = "data/US3001245R_Client_Data.sav"
w = com.robj.r('foreign::read.spss("%s", to.data.frame=TRUE)' % filename)
w = com.convert_robj(w)

# %%
w.head()
# Out:
#    RESPONDENT_SERIAL  QUOTA_COUNTRY  QLQ                       S1  \
# 1                6.0  United States  NaN  Upper-Level Management
# 2               14.0  United States  NaN  Middle-Level Management
# 3               16.0  United States  NaN  Middle-Level Management
# 4               17.0  United States  NaN  Middle-Level Management
# 5               22.0  United States  NaN  Upper-Level Management
#
#               S2                       S3                     S4  \
# 1       51 - 100       Very knowledgeable     Finance/Accounting
# 2  5,001 or more  Extremely knowledgeable         Administration
# 3       51 - 100   Somewhat knowledgeable        Human Resources
# 4       51 - 100  Extremely knowledgeable  Operations/Production
# 5   1,001- 5,000  Extremely knowledgeable        Human Resources
#
#                                                S4_95  \
# 1                                                ...
# 2                                                ...
# ...
